# %% [markdown]
# ## Expt.-7: Ensemble Learning for House Price Prediction
# ### Tanvi Santosh Patil         Roll No:53              Date:02.03.2026

# %%
import time
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
data = fetch_california_housing()
print(data.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
x = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

print(x.head())
print("samples:", len(x))
print(y[:10])
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88    -122.23
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86    -122.22
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85    -122.24
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85    -122.25
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85    -122.25
# samples: 20640
# [4.526 3.585 3.521 3.413 3.422 2.697 2.992 2.414 2.267 2.611]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x , y, test_size=0.2, random_state =42
)

# %% [markdown]
# ## Decision Tree

# %%
tree = DecisionTreeRegressor()

start = time.perf_counter()
tree.fit(x_train, y_train)
tree_time = time.perf_counter() - start

pred_tree_test = tree.predict(x_test)
err_tree_test = mean_absolute_error(y_test, pred_tree_test)
pred_tree_train = tree.predict(x_train)
err_tree_train = mean_absolute_error(y_train, pred_tree_train)

print("Decision Tree Train MAE:" , err_tree_train)
print("Decision Tree Test MAE:", err_tree_test)
print("Decision Tree Time:", tree_time)
# Out:
# Decision Tree Train MAE: 4.270916092792511e-17
# Decision Tree Test MAE: 0.4588213856589147
# Decision Tree Time: 0.24537110000005669

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestRegressor()

start = time.perf_counter()
rf.fit(x_train, y_train)
rf_time = time.perf_counter() - start

pred_rf_test = rf.predict(x_test)
err_rf_test = mean_absolute_error(y_test, pred_rf_test)
pred_rf_train = rf.predict(x_train)
err_rf_train = mean_absolute_error(y_train, pred_rf_train)

print("Random Forest Train MAE:" , err_rf_train)
print("Random Forest Test MAE:", err_rf_test)
print("Random Forest Time:", rf_time)
# Out:
# Random Forest Train MAE: 0.12127672334060118
# Random Forest Test MAE: 0.3271947494186048
# Random Forest Time: 16.99062980000008

# %% [markdown]
# # Gradient Boosting

# %%
gb = GradientBoostingRegressor(n_estimators=300, learning_rate=0.1, max_depth=5)

start = time.perf_counter()
gb.fit(x_train, y_train)
gb_time = time.perf_counter() - start

pred_gb_test = gb.predict(x_test)
err_gb_test = mean_absolute_error(y_test, pred_gb_test)
pred_gb_train = tree.predict(x_train)
err_gb_train = mean_absolute_error(y_train, pred_gb_train)

print("Gradient Boosting Train MAE:" , err_gb_train)
print("Gradient Boosting Test MAE:", err_gb_test)
print("Gradient Boosting Time:", gb_time)
# Out:
# Gradient Boosting Train MAE: 0.3566326593955599
# Gradient Boosting Test MAE: 0.30683190796372034
# Gradient Boosting Time: 21.550794499999938

# %%
print("\n----------Comparion For Test MAE----------")
print("Decision Tree Test:", err_tree_test)
print("Randon Forest Test:", err_rf_test)
print("Gradient Boosting Test:", err_gb_test)
# Out:
# ----------Comparion For Test MAE----------
# Decision Tree Test: 0.3716425690425596
# Randon Forest Test: 0.3271947494186048
# Gradient Boosting Test: 0.30683190796372034

# %%
print("\n----------Comparion For Train MAE----------")
print("Decision Tree Train:", err_tree_train)
print("Randon Forest Train:", err_rf_train)
print("Gradient Boosting Train:", err_gb_train)
# Out:
# ----------Comparion For Train MAE----------
# Decision Tree Train: 0.3566326593955599
# Randon Forest Train: 0.12127672334060118
# Gradient Boosting Train: 0.3566326593955599

# %%
print("\n----------Comparion For Test MAE----------")
print("Decision Tree time:", tree_time)
print("Randon Forest time:", rf_time)
print("Gradient Boosting Timr:", gb_time)
# Out:
# ----------Comparion For Test MAE----------
# Decision Tree time: 4.474977000000308
# Randon Forest time: 16.99062980000008
# Gradient Boosting Timr: 21.550794499999938
